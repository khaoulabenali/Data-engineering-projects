# %%
from drivers.scraper import Scraper
sc = Scraper()

# %%
sc.scrape_recipes('https://chefjackovens.com/recipes/',"results/chefjackovens.xlsx")
# Out:
# done scrolling
#  This blog is composed of 106 recipe.
# https://chefjackovens.com/chicken-yakitori/ ::::: Successfully saved!!
# Couldn't scrape total_prep_time
# https://chefjackovens.com/creamy-cajun-chicken-pasta/ ::::: Successfully saved!!
# https://chefjackovens.com/chicken-curry-meal-prep/ ::::: Successfully saved!!
# https://chefjackovens.com/beef-taco-bowl-meal-prep/ ::::: Successfully saved!!
# https://chefjackovens.com/sun-dried-tomato-pesto-pasta/ ::::: Successfully saved!!
# https://chefjackovens.com/chicken-caesar-salad/ ::::: Successfully saved!!
# https://chefjackovens.com/chilli-loaded-sweet-potatoes/ ::::: Successfully saved!!
# https://chefjackovens.com/chimichurri-chicken-meal-prep/ ::::: Successfully saved!!
# https://chefjackovens.com/breakfast-burrito-meal-prep/ ::::: Successfully saved!!
# https://chefjackovens.com/potato-bites-meal-prep/ ::::: Successfully saved!!
# https://chefjackovens.com/chicken-burrito-bowls/ ::::: Successfully saved!!
# ...
